# %% [markdown]
# # Методы сбора и обработки данных из Интернет

# %% [markdown]
# ## Урок 1. Практическое задание

# %% [markdown]
# ### Задание 1.
# Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
from pprint import pprint
import json

# %% [markdown]
# Выводим список репозиториев конкретного пользователя golda-gurr

# %%
def get_repositories(url):
    result = []
    r = requests.get(url=url)
    if 'next' in r.links :
        result += get_repositories(r.links['next']['url'])

    for repository in r.json():
        result.append(repository.get('name'))

    return result

# %%
url = "https://api.github.com/users/golda-gurr/repos"
print(get_repositories(url))
# Out:
# ['git-repo', 'git-repo2', 'git-repo3', 'python', 'python_ds', 'StartupIdeas']

# %% [markdown]
# Посмотрим, как сервер возвращает JSON формат

# %%
response = requests.get(url)

# %%
pprint(response.json())
# Out:
# [{'archive_url': 'https://api.github.com/repos/golda-gurr/git-repo/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/golda-gurr/git-repo/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/golda-gurr/git-repo/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/golda-gurr/git-repo/branches{/branch}',
#   'clone_url': 'https://github.com/golda-gurr/git-repo.git',
#   'collaborators_url': 'https://api.github.com/repos/golda-gurr/git-repo/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/golda-gurr/git-repo/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/golda-gurr/git-repo/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/golda-gurr/git-repo/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/golda-gurr/git-repo/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/golda-gurr/git-repo/contributors',
#   'created_at': '2019-10-02T17:40:13Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/golda-gurr/git-repo/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/golda-gurr/git-repo/downloads',
#   'events_url': 'https://api.github.com/repos/golda-gurr/git-repo/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/golda-gurr/git-repo/forks',
#   'full_name': 'golda-gurr/git-repo',
#   'git_commits_url': 'https://api.github.com/repos/golda-gurr/git-repo/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/golda-gurr/git-repo/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/golda-gurr/git-repo/git/tags{/sha}',
#   'git_url': 'git://github.com/golda-gurr/git-repo.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/golda-gurr/git-repo/hooks',
#   'html_url': 'https://github.com/golda-gurr/git-repo',
#   'id': 212403355,
#   'issue_comment_url': 'https://api.github.com/repos/golda-gurr/git-repo/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/golda-gurr/git-repo/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/golda-gurr/git-repo/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/golda-gurr/git-repo/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/golda-gurr/git-repo/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/golda-gurr/git-repo/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/golda-gurr/git-repo/merges',
#   'milestones_url': 'https://api.github.com/repos/golda-gurr/git-repo/milestones{/number}',
#   'mirror_url': None,
#   'name': 'git-repo',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTI0MDMzNTU=',
#   'notifications_url': 'https://api.github.com/repos/golda-gurr/git-repo/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/56088211?v=4',
#             'events_url': 'https://api.github.com/users/golda-gurr/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/golda-gurr/followers',
#             'following_url': 'https://api.github.com/users/golda-gurr/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/golda-gurr/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/golda-gurr',
#             'id': 56088211,
#             'login': 'golda-gurr',
#             'node_id': 'MDQ6VXNlcjU2MDg4MjEx',
#             'organizations_url': 'https://api.github.com/users/golda-gurr/orgs',
#             'received_events_url': 'https://api.github.com/users/golda-gurr/received_events',
#             'repos_url': 'https://api.github.com/users/golda-gurr/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/golda-gurr/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/golda-gurr/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/golda-gurr'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/golda-gurr/git-repo/pulls{/number}',
#   'pushed_at': '2019-10-12T14:58:45Z',
#   'releases_url': 'https://api.github.com/repos/golda-gurr/git-repo/releases{/id}',
#   'size': 4,
#   'ssh_url': 'git@github.com:golda-gurr/git-repo.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/golda-gurr/git-repo/stargazers',
#   'statuses_url': 'https://api.github.com/repos/golda-gurr/git-repo/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/golda-gurr/git-repo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/golda-gurr/git-repo/subscription',
#   'svn_url': 'https://github.com/golda-gurr/git-repo',
#   'tags_url': 'https://api.github.com/repos/golda-gurr/git-repo/tags',
#   'teams_url': 'https://api.github.com/repos/golda-gurr/git-repo/teams',
#   'trees_url': 'https://api.github.com/repos/golda-gurr/git-repo/git/trees{/sha}',
#   'updated_at': '2019-10-12T14:52:13Z',
#   'url': 'https://api.github.com/repos/golda-gurr/git-repo',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/golda-gurr/git-repo2/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/golda-gurr/git-repo2/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/golda-gurr/git-repo2/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/golda-gurr/git-repo2/branches{/branch}',
#   'clone_url': 'https://github.com/golda-gurr/git-repo2.git',
#   'collaborators_url': 'https://api.github.com/repos/golda-gurr/git-repo2/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/golda-gurr/git-repo2/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/golda-gurr/git-repo2/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/golda-gurr/git-repo2/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/golda-gurr/git-repo2/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/golda-gurr/git-repo2/contributors',
#   'created_at': '2019-10-05T13:36:19Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/golda-gurr/git-repo2/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/golda-gurr/git-repo2/downloads',
#   'events_url': 'https://api.github.com/repos/golda-gurr/git-repo2/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/golda-gurr/git-repo2/forks',
#   'full_name': 'golda-gurr/git-repo2',
#   'git_commits_url': 'https://api.github.com/repos/golda-gurr/git-repo2/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/golda-gurr/git-repo2/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/golda-gurr/git-repo2/git/tags{/sha}',
#   'git_url': 'git://github.com/golda-gurr/git-repo2.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/golda-gurr/git-repo2/hooks',
#   'html_url': 'https://github.com/golda-gurr/git-repo2',
#   'id': 213005319,
#   'issue_comment_url': 'https://api.github.com/repos/golda-gurr/git-repo2/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/golda-gurr/git-repo2/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/golda-gurr/git-repo2/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/golda-gurr/git-repo2/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/golda-gurr/git-repo2/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/golda-gurr/git-repo2/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/golda-gurr/git-repo2/merges',
#   'milestones_url': 'https://api.github.com/repos/golda-gurr/git-repo2/milestones{/number}',
#   'mirror_url': None,
#   'name': 'git-repo2',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTMwMDUzMTk=',
#   'notifications_url': 'https://api.github.com/repos/golda-gurr/git-repo2/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/56088211?v=4',
#             'events_url': 'https://api.github.com/users/golda-gurr/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/golda-gurr/followers',
#             'following_url': 'https://api.github.com/users/golda-gurr/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/golda-gurr/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/golda-gurr',
#             'id': 56088211,
#             'login': 'golda-gurr',
#             'node_id': 'MDQ6VXNlcjU2MDg4MjEx',
#             'organizations_url': 'https://api.github.com/users/golda-gurr/orgs',
#             'received_events_url': 'https://api.github.com/users/golda-gurr/received_events',
#             'repos_url': 'https://api.github.com/users/golda-gurr/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/golda-gurr/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/golda-gurr/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/golda-gurr'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/golda-gurr/git-repo2/pulls{/number}',
#   'pushed_at': '2019-10-07T17:50:51Z',
#   'releases_url': 'https://api.github.com/repos/golda-gurr/git-repo2/releases{/id}',
#   'size': 3,
#   'ssh_url': 'git@github.com:golda-gurr/git-repo2.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/golda-gurr/git-repo2/stargazers',
#   'statuses_url': 'https://api.github.com/repos/golda-gurr/git-repo2/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/golda-gurr/git-repo2/subscribers',
#   'subscription_url': 'https://api.github.com/repos/golda-gurr/git-repo2/subscription',
#   'svn_url': 'https://github.com/golda-gurr/git-repo2',
#   'tags_url': 'https://api.github.com/repos/golda-gurr/git-repo2/tags',
#   'teams_url': 'https://api.github.com/repos/golda-gurr/git-repo2/teams',
#   'trees_url': 'https://api.github.com/repos/golda-gurr/git-repo2/git/trees{/sha}',
#   'updated_at': '2019-10-07T17:50:53Z',
#   'url': 'https://api.github.com/repos/golda-gurr/git-repo2',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/golda-gurr/git-repo3/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/golda-gurr/git-repo3/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/golda-gurr/git-repo3/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/golda-gurr/git-repo3/branches{/branch}',
#   'clone_url': 'https://github.com/golda-gurr/git-repo3.git',
#   'collaborators_url': 'https://api.github.com/repos/golda-gurr/git-repo3/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/golda-gurr/git-repo3/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/golda-gurr/git-repo3/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/golda-gurr/git-repo3/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/golda-gurr/git-repo3/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/golda-gurr/git-repo3/contributors',
#   'created_at': '2019-10-05T14:01:41Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/golda-gurr/git-repo3/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/golda-gurr/git-repo3/downloads',
#   'events_url': 'https://api.github.com/repos/golda-gurr/git-repo3/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/golda-gurr/git-repo3/forks',
#   'full_name': 'golda-gurr/git-repo3',
#   'git_commits_url': 'https://api.github.com/repos/golda-gurr/git-repo3/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/golda-gurr/git-repo3/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/golda-gurr/git-repo3/git/tags{/sha}',
#   'git_url': 'git://github.com/golda-gurr/git-repo3.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/golda-gurr/git-repo3/hooks',
#   'html_url': 'https://github.com/golda-gurr/git-repo3',
#   'id': 213009417,
#   'issue_comment_url': 'https://api.github.com/repos/golda-gurr/git-repo3/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/golda-gurr/git-repo3/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/golda-gurr/git-repo3/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/golda-gurr/git-repo3/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/golda-gurr/git-repo3/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/golda-gurr/git-repo3/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/golda-gurr/git-repo3/merges',
#   'milestones_url': 'https://api.github.com/repos/golda-gurr/git-repo3/milestones{/number}',
#   'mirror_url': None,
#   'name': 'git-repo3',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTMwMDk0MTc=',
#   'notifications_url': 'https://api.github.com/repos/golda-gurr/git-repo3/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/56088211?v=4',
#             'events_url': 'https://api.github.com/users/golda-gurr/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/golda-gurr/followers',
#             'following_url': 'https://api.github.com/users/golda-gurr/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/golda-gurr/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/golda-gurr',
#             'id': 56088211,
#             'login': 'golda-gurr',
#             'node_id': 'MDQ6VXNlcjU2MDg4MjEx',
#             'organizations_url': 'https://api.github.com/users/golda-gurr/orgs',
#             'received_events_url': 'https://api.github.com/users/golda-gurr/received_events',
#             'repos_url': 'https://api.github.com/users/golda-gurr/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/golda-gurr/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/golda-gurr/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/golda-gurr'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/golda-gurr/git-repo3/pulls{/number}',
#   'pushed_at': '2019-10-07T17:58:18Z',
#   'releases_url': 'https://api.github.com/repos/golda-gurr/git-repo3/releases{/id}',
#   'size': 2,
#   'ssh_url': 'git@github.com:golda-gurr/git-repo3.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/golda-gurr/git-repo3/stargazers',
#   'statuses_url': 'https://api.github.com/repos/golda-gurr/git-repo3/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/golda-gurr/git-repo3/subscribers',
#   'subscription_url': 'https://api.github.com/repos/golda-gurr/git-repo3/subscription',
#   'svn_url': 'https://github.com/golda-gurr/git-repo3',
#   'tags_url': 'https://api.github.com/repos/golda-gurr/git-repo3/tags',
#   'teams_url': 'https://api.github.com/repos/golda-gurr/git-repo3/teams',
#   'trees_url': 'https://api.github.com/repos/golda-gurr/git-repo3/git/trees{/sha}',
#   'updated_at': '2019-10-07T17:54:54Z',
#   'url': 'https://api.github.com/repos/golda-gurr/git-repo3',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/golda-gurr/python/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/golda-gurr/python/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/golda-gurr/python/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/golda-gurr/python/branches{/branch}',
#   'clone_url': 'https://github.com/golda-gurr/python.git',
#   'collaborators_url': 'https://api.github.com/repos/golda-gurr/python/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/golda-gurr/python/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/golda-gurr/python/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/golda-gurr/python/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/golda-gurr/python/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/golda-gurr/python/contributors',
#   'created_at': '2019-10-06T09:21:19Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/golda-gurr/python/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/golda-gurr/python/downloads',
#   'events_url': 'https://api.github.com/repos/golda-gurr/python/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/golda-gurr/python/forks',
#   'full_name': 'golda-gurr/python',
#   'git_commits_url': 'https://api.github.com/repos/golda-gurr/python/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/golda-gurr/python/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/golda-gurr/python/git/tags{/sha}',
#   'git_url': 'git://github.com/golda-gurr/python.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/golda-gurr/python/hooks',
#   'html_url': 'https://github.com/golda-gurr/python',
#   'id': 213139870,
#   'issue_comment_url': 'https://api.github.com/repos/golda-gurr/python/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/golda-gurr/python/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/golda-gurr/python/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/golda-gurr/python/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/golda-gurr/python/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/golda-gurr/python/languages',
#   'license': {'key': 'gpl-3.0',
#               'name': 'GNU General Public License v3.0',
#               'node_id': 'MDc6TGljZW5zZTk=',
#               'spdx_id': 'GPL-3.0',
#               'url': 'https://api.github.com/licenses/gpl-3.0'},
#   'merges_url': 'https://api.github.com/repos/golda-gurr/python/merges',
#   'milestones_url': 'https://api.github.com/repos/golda-gurr/python/milestones{/number}',
#   'mirror_url': None,
#   'name': 'python',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTMxMzk4NzA=',
#   'notifications_url': 'https://api.github.com/repos/golda-gurr/python/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/56088211?v=4',
#             'events_url': 'https://api.github.com/users/golda-gurr/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/golda-gurr/followers',
#             'following_url': 'https://api.github.com/users/golda-gurr/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/golda-gurr/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/golda-gurr',
#             'id': 56088211,
#             'login': 'golda-gurr',
#             'node_id': 'MDQ6VXNlcjU2MDg4MjEx',
#             'organizations_url': 'https://api.github.com/users/golda-gurr/orgs',
#             'received_events_url': 'https://api.github.com/users/golda-gurr/received_events',
#             'repos_url': 'https://api.github.com/users/golda-gurr/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/golda-gurr/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/golda-gurr/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/golda-gurr'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/golda-gurr/python/pulls{/number}',
#   'pushed_at': '2019-10-06T10:25:27Z',
#   'releases_url': 'https://api.github.com/repos/golda-gurr/python/releases{/id}',
#   'size': 15,
#   'ssh_url': 'git@github.com:golda-gurr/python.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/golda-gurr/python/stargazers',
#   'statuses_url': 'https://api.github.com/repos/golda-gurr/python/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/golda-gurr/python/subscribers',
#   'subscription_url': 'https://api.github.com/repos/golda-gurr/python/subscription',
#   'svn_url': 'https://github.com/golda-gurr/python',
#   'tags_url': 'https://api.github.com/repos/golda-gurr/python/tags',
#   'teams_url': 'https://api.github.com/repos/golda-gurr/python/teams',
#   'trees_url': 'https://api.github.com/repos/golda-gurr/python/git/trees{/sha}',
#   'updated_at': '2019-10-06T10:25:29Z',
#   'url': 'https://api.github.com/repos/golda-gurr/python',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/golda-gurr/python_ds/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/golda-gurr/python_ds/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/golda-gurr/python_ds/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/golda-gurr/python_ds/branches{/branch}',
#   'clone_url': 'https://github.com/golda-gurr/python_ds.git',
#   'collaborators_url': 'https://api.github.com/repos/golda-gurr/python_ds/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/golda-gurr/python_ds/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/golda-gurr/python_ds/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/golda-gurr/python_ds/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/golda-gurr/python_ds/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/golda-gurr/python_ds/contributors',
#   'created_at': '2020-05-07T17:01:34Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/golda-gurr/python_ds/deployments',
#   'description': 'Библиотеки Python для Data Science: Numpy, Matplotlib, '
#                  'Scikit-learn',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/golda-gurr/python_ds/downloads',
#   'events_url': 'https://api.github.com/repos/golda-gurr/python_ds/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/golda-gurr/python_ds/forks',
#   'full_name': 'golda-gurr/python_ds',
#   'git_commits_url': 'https://api.github.com/repos/golda-gurr/python_ds/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/golda-gurr/python_ds/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/golda-gurr/python_ds/git/tags{/sha}',
#   'git_url': 'git://github.com/golda-gurr/python_ds.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/golda-gurr/python_ds/hooks',
#   'html_url': 'https://github.com/golda-gurr/python_ds',
#   'id': 262109683,
#   'issue_comment_url': 'https://api.github.com/repos/golda-gurr/python_ds/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/golda-gurr/python_ds/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/golda-gurr/python_ds/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/golda-gurr/python_ds/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/golda-gurr/python_ds/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/golda-gurr/python_ds/languages',
#   'license': {'key': 'gpl-3.0',
#               'name': 'GNU General Public License v3.0',
#               'node_id': 'MDc6TGljZW5zZTk=',
#               'spdx_id': 'GPL-3.0',
#               'url': 'https://api.github.com/licenses/gpl-3.0'},
#   'merges_url': 'https://api.github.com/repos/golda-gurr/python_ds/merges',
#   'milestones_url': 'https://api.github.com/repos/golda-gurr/python_ds/milestones{/number}',
#   'mirror_url': None,
#   'name': 'python_ds',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjIxMDk2ODM=',
#   'notifications_url': 'https://api.github.com/repos/golda-gurr/python_ds/notifications{?since,all,participating}',
#   'open_issues': 5,
#   'open_issues_count': 5,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/56088211?v=4',
#             'events_url': 'https://api.github.com/users/golda-gurr/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/golda-gurr/followers',
#             'following_url': 'https://api.github.com/users/golda-gurr/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/golda-gurr/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/golda-gurr',
#             'id': 56088211,
#             'login': 'golda-gurr',
#             'node_id': 'MDQ6VXNlcjU2MDg4MjEx',
#             'organizations_url': 'https://api.github.com/users/golda-gurr/orgs',
#             'received_events_url': 'https://api.github.com/users/golda-gurr/received_events',
#             'repos_url': 'https://api.github.com/users/golda-gurr/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/golda-gurr/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/golda-gurr/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/golda-gurr'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/golda-gurr/python_ds/pulls{/number}',
#   'pushed_at': '2020-06-11T16:29:09Z',
#   'releases_url': 'https://api.github.com/repos/golda-gurr/python_ds/releases{/id}',
#   'size': 652,
#   'ssh_url': 'git@github.com:golda-gurr/python_ds.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/golda-gurr/python_ds/stargazers',
#   'statuses_url': 'https://api.github.com/repos/golda-gurr/python_ds/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/golda-gurr/python_ds/subscribers',
#   'subscription_url': 'https://api.github.com/repos/golda-gurr/python_ds/subscription',
#   'svn_url': 'https://github.com/golda-gurr/python_ds',
#   'tags_url': 'https://api.github.com/repos/golda-gurr/python_ds/tags',
#   'teams_url': 'https://api.github.com/repos/golda-gurr/python_ds/teams',
#   'trees_url': 'https://api.github.com/repos/golda-gurr/python_ds/git/trees{/sha}',
#   'updated_at': '2020-05-07T17:01:44Z',
#   'url': 'https://api.github.com/repos/golda-gurr/python_ds',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/branches{/branch}',
#   'clone_url': 'https://github.com/golda-gurr/StartupIdeas.git',
#   'collaborators_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/contributors',
#   'created_at': '2019-10-06T08:51:20Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/downloads',
#   'events_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/events',
#   'fork': True,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/forks',
#   'full_name': 'golda-gurr/StartupIdeas',
#   'git_commits_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/git/tags{/sha}',
#   'git_url': 'git://github.com/golda-gurr/StartupIdeas.git',
#   'has_downloads': True,
#   'has_issues': False,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/hooks',
#   'html_url': 'https://github.com/golda-gurr/StartupIdeas',
#   'id': 213135944,
#   'issue_comment_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/merges',
#   'milestones_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/milestones{/number}',
#   'mirror_url': None,
#   'name': 'StartupIdeas',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTMxMzU5NDQ=',
#   'notifications_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/56088211?v=4',
#             'events_url': 'https://api.github.com/users/golda-gurr/events{/privacy}',
#             'followers_url': 'https://api.github.com/users/golda-gurr/followers',
#             'following_url': 'https://api.github.com/users/golda-gurr/following{/other_user}',
#             'gists_url': 'https://api.github.com/users/golda-gurr/gists{/gist_id}',
#             'gravatar_id': '',
#             'html_url': 'https://github.com/golda-gurr',
#             'id': 56088211,
#             'login': 'golda-gurr',
#             'node_id': 'MDQ6VXNlcjU2MDg4MjEx',
#             'organizations_url': 'https://api.github.com/users/golda-gurr/orgs',
#             'received_events_url': 'https://api.github.com/users/golda-gurr/received_events',
#             'repos_url': 'https://api.github.com/users/golda-gurr/repos',
#             'site_admin': False,
#             'starred_url': 'https://api.github.com/users/golda-gurr/starred{/owner}{/repo}',
#             'subscriptions_url': 'https://api.github.com/users/golda-gurr/subscriptions',
#             'type': 'User',
#             'url': 'https://api.github.com/users/golda-gurr'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/pulls{/number}',
#   'pushed_at': '2019-10-06T09:04:37Z',
#   'releases_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/releases{/id}',
#   'size': 6,
#   'ssh_url': 'git@github.com:golda-gurr/StartupIdeas.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/stargazers',
#   'statuses_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/subscribers',
#   'subscription_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/subscription',
#   'svn_url': 'https://github.com/golda-gurr/StartupIdeas',
#   'tags_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/tags',
#   'teams_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/teams',
#   'trees_url': 'https://api.github.com/repos/golda-gurr/StartupIdeas/git/trees{/sha}',
#   'updated_at': '2019-10-06T09:04:41Z',
#   'url': 'https://api.github.com/repos/golda-gurr/StartupIdeas',
#   'watchers': 0,
#   'watchers_count': 0}]

# %% [markdown]
# В json сохраняем весь ответ от сервера

# %%
response = requests.get(url)
response.raise_for_status()
data = response.json()
with open('response.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, indent=2, ensure_ascii=False)

# %% [markdown]
# ### Задание 2.
# Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.
#
# Если нет желания заморачиваться с поиском, возьмите API вконтакте (https://vk.com/dev/first_guide). Сделайте запрос, чтобы получить список всех сообществ на которые вы подписаны.

# %%
# Метод groups.get возвращает список сообществ указанного пользователя.
# https://api.vk.com/method/groups.get?v=5.52&access_token=

main_link = 'https://api.vk.com/method/groups.get?v=5.52'

# %%
access_token = '' # нужно вставить уникальный ключ пользователя vk.com

# %%
response_vk = requests.get(f'{main_link}&access_token={access_token}')

# %%
print(response_vk.json())
# Out:
# {'response': {'count': 2, 'items': [91453124, 153646673]}}

# %%
response_vk.raise_for_status()
data = response_vk.json()
with open('response_vk.json', 'w', encoding='utf-8') as file:
    json.dump(data, file, indent=2, ensure_ascii=False)
